# %%
import tensorflow as tf
from tensorflow import keras
import matplotlib.pyplot as plt
from mobilenet_models import create_mobilenetv3_large_model, create_mobilenetv3_small_model
import wandb
from wandb.keras import WandbCallback
import os
# Out:
# 2023-10-21 13:15:50.741546: I tensorflow/core/platform/cpu_feature_guard.cc:183] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: SSE3 SSE4.1 SSE4.2 AVX, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
train_ds = keras.utils.image_dataset_from_directory(
    directory="train",
    labels='inferred',
    label_mode='categorical',
    shuffle=True,
    batch_size=32,
    image_size=(224, 224)
    )
val_ds = keras.utils.image_dataset_from_directory(
    directory="validation",
    labels='inferred',
    label_mode='categorical',
    shuffle=True,
    batch_size=32,
    image_size=(224, 224)
    )
# Out:
# Found 22320 files belonging to 15 classes.
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File /usr/local/lib/python3.10/dist-packages/tensorflow/python/data/util/structure.py:104, in normalize_element(element, element_signature)
#     103   if spec is None:
# --> 104     spec = type_spec_from_value(t, use_fallback=False)
#     105 except TypeError:
#     106   # TypeError indicates it was not possible to compute a `TypeSpec` for
#     107   # the value. As a fallback try converting the value to a tensor.
#
# File /usr/local/lib/python3.10/dist-packages/tensorflow/python/data/util/structure.py:507, in type_spec_from_value(element, use_fallback)
#     504     logging.vlog(
#     505         3, "Failed to convert %r to tensor: %s" % (type(element).__name__, e))
# --> 507 raise TypeError("Could not build a `TypeSpec` for {} with type {}".format(
#     508     element,
#     509     type(element).__name__))
#
# TypeError: Could not build a `TypeSpec` for ['train/detritus/BUC 2013 ST 22 A_003694.jpg', 'train/ciliate/IHLS092016_001_001678.jpg', 'train/copepod/BUC 2013 ST 11 A_000767.jpg', 'train/copepod/IHLS_2013_58B_002761.jpg', 'train/detritus/IHLS_2013_34B_004783 - Kopie.jpg', 'train/copepod/BUC 2013 ST 11 A_009395.jpg', 'train/detritus/BUC 2013 ST 22 A_000974.jpg', 'train/detritus/BUC 2013 ST 11 A_010569.jpg', 'train/detritus/IHLS_2017_29E_001720.jpg', 'train/ceratium/IHLS092018_123_015475.jpg', 'train/gastropoda/BUC 2013 ST 69 A_014436.jpg', 'train/detritus/BUC 2013 ST 11 A_013582.jpg', 'train/dinoflagellate/IHLS092013_097_002344.jpg', 'train/diatom/BUC 2013 ST 11 A_014543.jpg', 'train/diatom/IHLS092016_016_006609.jpg', 'train/ceratium/IHLS092018_140_004234.jpg', 'train/diatom/P99-0-0_IHLS092018_140_012003.jpg', 'train/gastropoda/BUC 2013 ST 69 A_013526.jpg', 'train/diatom/P99-0-0_IHLS092018_140_004899.jpg', 'train/detritus/IHLS092018_037_010344.jpg', 'train/ciliate/IHLS092018_097_013223.jpg', 'train/detritus/BUC 2013 ST 69 A_003424.jpg', 'train/gastropoda/BUC 2013 ST 69 A_014470.jpg', 'train/detritus/IHLS092018_021_000271.jpg', 'train/clumps/IHLS_2013_17C_001900.jpg', 'train/detritus/BUC 2013 ST 69 A_015428.jpg', 'train/detritus/BUC 2013 ST 11 A_002692.jpg', 'train/detritus/IHLS_2017_29E_005087.jpg', 'train/detritus/BUC 2013 ST 11 A_000722.jpg', 'train/dinophysis/IHLS092016_009_008478.jpg', 'train/copepod/BUC 2013 ST 11 A_012375.jpg', 'train/diatom/P99-0-0_IHLS092018_140_000566.jpg', 'train/diatom/P99-0-0_IHLS092018_140_007746.jpg', 'train/clumps/IHLS_2015_36B_004309.jpg', 'train/detritus/BUC 2013 ST 22 A_006329.jpg', 'train/ceratium/BUC 2013 ST 69 A_011497.jpg', 'train/clumps/IHLS_2013_22B_007987.jpg', 'train/detritus/BUC 2013 ST 11 A_006173.jpg', 'train/copepod/IHLS_2013_26C_000822.jpg', 'train/dinophysis/BUC_2013_ST_4_004078.jpg', 'train/ceratium/IHLS092016_024_007463.jpg', 'train/bivalve/P91-3-1_IHLS092017_064_010315.jpg', 'train/diatom/dinoflagellateP40-33-13_dinoflagellateP40-33-13_IHLS092018_003_010253.jpg', 'train/ciliate/IHLS092013_043_010386.jpg', 'train/copepod/BUC 2013 ST 11 A_009722.jpg', 'train/detritus/BUC 2013 ST 11 A_002985.jpg', 'train/copepod/IHLS_2017_70B_001213.jpg', 'train/gastropoda/BUC 2013 ST 69 A_009005.jpg', 'train/copepod/BUC 2013 ST 11 A_006751.jpg', 'train/copepod/P82-7-3_P82-7-3_IHLS092018_003_001375.jpg', 'train/detritus/BUC 2013 ST 69 A_002863.jpg', 'train/clumps/P95-4-0_P95-4-0_IHLS092018_008_001966.jpg', 'train/detritus/BUC 2013 ST 11 A_002086.jpg', 'train/ceratium/BUC 2013 ST 69 A_007230.jpg', 'train/protoperidinium/IHLS_2017_9B_005040.jpg', 'train/gastropoda/BUC 2013 ST 22 A_007541.jpg', 'train/diatom/P99-0-0_IHLS092018_140_004249.jpg', 'train/gastropoda/P93-2-2_P93-2-2_IHLS092018_008_007295.jpg', 'train/detritus/BUC 2013 ST 11 A_013732.jpg', 'train/copepod/IHLS_2013_54B_004290.jpg', 'train/copepod/IHLS_2017_45C_001011.jpg', 'train/copepod/BUC 2013 ST 69 A_013942.jpg', 'train/dinoflagellate/IHLS122018_016_000171.jpg', 'train/detritus/BUC 2013 ST 69 A_003892.jpg', 'train/copepod/BUC 2013 ST 22 A_000785.jpg', 'train/protoperidinium/dinoflagellateP51-39-7_dinoflagellateP51-39-7_IHLS092018_026_008783.jpg', 'train/clumps/IHLS_2015_36B_003090.jpg', 'train/protoperidinium/protoperidiniumP34-32-30_protoperidiniumP34-32-30_IHLS092018_008_004068.jpg', 'train/protoperidinium/BUC 2013 ST 11 A_003270.jpg', 'train/detritus/IHLS_2017_29E_003528.jpg', 'train/detritus/BUC 2013 ST 69 A_003962.jpg', 'train/gastropoda/BUC 2013 ST 11 A_005346.jpg', 'train/clumps/IHLS_2013_34B_001230.jpg', 'train/copepod/BUC 2013 ST 22 A_007869.jpg', 'train/copepod/BUC 2013 ST 22 A_005497.jpg', 'train/diatom/P87-11-0_P87-11-0_IHLS092018_021_008747.jpg', 'train/dinophysis/BUC_2013_ST_4_008395.jpg', 'train/detritus/BUC 2013 ST 22 A_003266.jpg', 'train/detritus/BUC 2013 ST 69 A_011225.jpg', 'train/foraminifera/IHLS_2013_57C_003658.jpg', 'train/bivalve/P95-3-0_IHLS092017_048_011505.jpg', 'train/ciliate/IHLS092018_097_008541.jpg', 'trai ...
#
# During handling of the above exception, another exception occurred:
#
# InternalError                             Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 train_ds = keras.utils.image_dataset_from_directory(
#       2     directory="train",
#       3     labels='inferred',
#       4     label_mode='categorical',
#       5     shuffle=True,
#       6     batch_size=32,
#       7     image_size=(224, 224)
#       8     )
#       9 val_ds = keras.utils.image_dataset_from_directory(
#      10     directory="validation",
#      11     labels='inferred',
#    (...)
#      15     image_size=(224, 224)
#      16     )
#
# File ~/.local/lib/python3.10/site-packages/keras/utils/image_dataset.py:302, in image_dataset_from_directory(directory, labels, label_mode, class_names, color_mode, batch_size, image_size, shuffle, seed, validation_split, subset, interpolation, follow_links, crop_to_aspect_ratio, **kwargs)
#     296 if not image_paths:
#     297     raise ValueError(
#     298         f"No images found in directory {directory}. "
#     299         f"Allowed formats: {ALLOWLIST_FORMATS}"
#     300     )
# --> 302 dataset = paths_and_labels_to_dataset(
#     303     image_paths=image_paths,
#     304     image_size=image_size,
#     305     num_channels=num_channels,
#     306     labels=labels,
#     307     label_mode=label_mode,
#     308     num_classes=len(class_names),
#     309     interpolation=interpolation,
#     310     crop_to_aspect_ratio=crop_to_aspect_ratio,
#     311 )
#     312 dataset = dataset.prefetch(tf.data.AUTOTUNE)
#     313 if batch_size is not None:
#
# File ~/.local/lib/python3.10/site-packages/keras/utils/image_dataset.py:341, in paths_and_labels_to_dataset(image_paths, image_size, num_channels, labels, label_mode, num_classes, interpolation, crop_to_aspect_ratio)
#     339 """Constructs a dataset of images and labels."""
#     340 # TODO(fchollet): consider making num_parallel_calls settable
# --> 341 path_ds = tf.data.Dataset.from_tensor_slices(image_paths)
#     342 args = (image_size, num_channels, interpolation, crop_to_aspect_ratio)
#     343 img_ds = path_ds.map(
#     344     lambda x: load_image(x, *args), num_parallel_calls=tf.data.AUTOTUNE
#     345 )
#
# File /usr/local/lib/python3.10/dist-packages/tensorflow/python/data/ops/dataset_ops.py:831, in DatasetV2.from_tensor_slices(tensors, name)
#     827 # Loaded lazily due to a circular dependency (dataset_ops ->
#     828 # from_tensor_slices_op -> dataset_ops).
#     829 # pylint: disable=g-import-not-at-top,protected-access
#     830 from tensorflow.python.data.ops import from_tensor_slices_op
# --> 831 return from_tensor_slices_op._from_tensor_slices(tensors, name)
#
# File /usr/local/lib/python3.10/dist-packages/tensorflow/python/data/ops/from_tensor_slices_op.py:25, in _from_tensor_slices(tensors, name)
#      24 def _from_tensor_slices(tensors, name=None):
# ---> 25   return _TensorSliceDataset(tensors, name=name)
#
# File /usr/local/lib/python3.10/dist-packages/tensorflow/python/data/ops/from_tensor_slices_op.py:33, in _TensorSliceDataset.__init__(self, element, is_files, name)
#      31 def __init__(self, element, is_files=False, name=None):
#      32   """See `Dataset.from_tensor_slices` for details."""
# ---> 33   element = structure.normalize_element(element)
#      34   batched_spec = structure.type_spec_from_value(element)
#      35   self._tensors = structure.to_batched_tensor_list(batched_spec, element)
#
# File /usr/local/lib/python3.10/dist-packages/tensorflow/python/data/util/structure.py:109, in normalize_element(element, element_signature)
#     104     spec = type_spec_from_value(t, use_fallback=False)
#     105 except TypeError:
#     106   # TypeError indicates it was not possible to compute a `TypeSpec` for
#     107   # the value. As a fallback try converting the value to a tensor.
#     108   normalized_components.append(
# --> 109       ops.convert_to_tensor(t, name="component_%d" % i))
#     110 else:
#     111   # To avoid a circular dependency between dataset_ops and structure,
#     112   # we check the class name instead of using `isinstance`.
#     113   if spec.__class__.__name__ == "DatasetSpec":
#
# File /usr/local/lib/python3.10/dist-packages/tensorflow/python/profiler/trace.py:183, in trace_wrapper.<locals>.inner_wrapper.<locals>.wrapped(*args, **kwargs)
#     181   with Trace(trace_name, **trace_kwargs):
#     182     return func(*args, **kwargs)
# --> 183 return func(*args, **kwargs)
#
# File /usr/local/lib/python3.10/dist-packages/tensorflow/python/framework/ops.py:1443, in convert_to_tensor(value, dtype, name, as_ref, preferred_dtype, dtype_hint, ctx, accepted_result_types)
#    1441 # TODO(b/142518781): Fix all call-sites and remove redundant arg
#    1442 preferred_dtype = preferred_dtype or dtype_hint
# -> 1443 return tensor_conversion_registry.convert(
#    1444     value, dtype, name, as_ref, preferred_dtype, accepted_result_types
#    1445 )
#
# File /usr/local/lib/python3.10/dist-packages/tensorflow/python/framework/tensor_conversion_registry.py:234, in convert(value, dtype, name, as_ref, preferred_dtype, accepted_result_types)
#     225       raise RuntimeError(
#     226           _add_error_prefix(
#     227               f"Conversion function {conversion_func!r} for type "
#    (...)
#     230               f"actual = {ret.dtype.base_dtype.name}",
#     231               name=name))
#     233 if ret is None:
# --> 234   ret = conversion_func(value, dtype=dtype, name=name, as_ref=as_ref)
#     236 if ret is NotImplemented:
#     237   continue
#
# File /usr/local/lib/python3.10/dist-packages/tensorflow/python/framework/constant_op.py:324, in _constant_tensor_conversion_function(v, dtype, name, as_ref)
#     321 def _constant_tensor_conversion_function(v, dtype=None, name=None,
#     322                                          as_ref=False):
#     323   _ = as_ref
# --> 324   return constant(v, dtype=dtype, name=name)
#
# File /usr/local/lib/python3.10/dist-packages/tensorflow/python/framework/constant_op.py:263, in constant(value, dtype, shape, name)
#     166 @tf_export("constant", v1=[])
#     167 def constant(value, dtype=None, shape=None, name="Const"):
#     168   """Creates a constant tensor from a tensor-like object.
#     169
#     170   Note: All eager `tf.Tensor` values are immutable (in contrast to
#    (...)
#     261     ValueError: if called on a symbolic tensor.
#     262   """
# --> 263   return _constant_impl(value, dtype, shape, name, verify_shape=False,
#     264                         allow_broadcast=True)
#
# File /usr/local/lib/python3.10/dist-packages/tensorflow/python/framework/constant_op.py:275, in _constant_impl(value, dtype, shape, name, verify_shape, allow_broadcast)
#     273     with trace.Trace("tf.constant"):
#     274       return _constant_eager_impl(ctx, value, dtype, shape, verify_shape)
# --> 275   return _constant_eager_impl(ctx, value, dtype, shape, verify_shape)
#     277 const_tensor = ops._create_graph_constant(  # pylint: disable=protected-access
#     278     value, dtype, shape, name, verify_shape, allow_broadcast
#     279 )
#     280 return const_tensor
#
# File /usr/local/lib/python3.10/dist-packages/tensorflow/python/framework/constant_op.py:285, in _constant_eager_impl(ctx, value, dtype, shape, verify_shape)
#     283 def _constant_eager_impl(ctx, value, dtype, shape, verify_shape):
#     284   """Creates a constant on the current device."""
# --> 285   t = convert_to_eager_tensor(value, ctx, dtype)
#     286   if shape is None:
#     287     return t
#
# File /usr/local/lib/python3.10/dist-packages/tensorflow/python/framework/constant_op.py:97, in convert_to_eager_tensor(value, ctx, dtype)
#      95   except AttributeError:
#      96     dtype = dtypes.as_dtype(dtype).as_datatype_enum
# ---> 97 ctx.ensure_initialized()
#      98 return ops.EagerTensor(value, ctx.device_name, dtype)
#
# File /usr/local/lib/python3.10/dist-packages/tensorflow/python/eager/context.py:596, in Context.ensure_initialized(self)
#     593   pywrap_tfe.TFE_ContextOptionsSetRunEagerOpAsFunction(opts, True)
#     594   pywrap_tfe.TFE_ContextOptionsSetJitCompileRewrite(
#     595       opts, self._jit_compile_rewrite)
# --> 596   context_handle = pywrap_tfe.TFE_NewContext(opts)
#     597 finally:
#     598   pywrap_tfe.TFE_DeleteContextOptions(opts)
#
# InternalError: cudaSetDevice() on GPU:0 failed. Status: out of memory

# %%
# initialize wandb
wandb.init(project="MobileNet", config={"learning_rate": 0.001, "epochs": 30, "verbose": 1,"name": "MobileNetV3Large", "architecture": "MobileNetV3Large"})

# configs
cfg = wandb.config

# create the model
model = create_mobilenetv3_large_model(len(train_ds.class_names))
# Out:
# wandb: Currently logged in as: katrina97 (team-fall23). Use `wandb login --relogin` to force relogin
# Tracking run with wandb version 0.15.12
# Run data is saved locally in <code>/home/katril18/DOC_prev_code/plankton_classification/models/mobilenet/wandb/run-20231021_122720-znuoe7jj</code>
# Syncing run <strong><a href='https://wandb.ai/team-fall23/MobileNet/runs/znuoe7jj' target="_blank">fast-sea-3</a></strong> to <a href='https://wandb.ai/team-fall23/MobileNet' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>
#  View project at <a href='https://wandb.ai/team-fall23/MobileNet' target="_blank">https://wandb.ai/team-fall23/MobileNet</a>
#  View run at <a href='https://wandb.ai/team-fall23/MobileNet/runs/znuoe7jj' target="_blank">https://wandb.ai/team-fall23/MobileNet/runs/znuoe7jj</a>
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 8
#       5 cfg = wandb.config
#       7 # create the model
# ----> 8 model = create_mobilenetv3_large_model(len(train_ds.class_names))
#
# NameError: name 'train_ds' is not defined

# %%
# list of callbacks
callbacks = [
            WandbCallback(mode="min", monitor="val_loss", save_graph=True),
            tf.keras.callbacks.ReduceLROnPlateau(monitor='val_loss', factor=0.1,
                              patience=3, min_lr=0.00001),
            tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=5),
          ]

# %%
model.fit(train_ds, epochs=cfg.epochs, batch_size=32, verbose=cfg.verbose, validation_data=val_ds, callbacks=callbacks) # train the model
# Out:
# Epoch 1/30
# 2023-03-23 23:31:46.228131: I tensorflow/stream_executor/cuda/cuda_dnn.cc:377] Loaded cuDNN version 8302
# 9306/9306 [==============================] - 334s 35ms/step - loss: 0.2463 - accuracy: 0.9239 - val_loss: 0.1708 - val_accuracy: 0.9477
# /usr/local/lib/python3.8/dist-packages/keras/utils/generic_utils.py:494: CustomMaskWarning: Custom mask layers require a config and must override get_config. When loading, the custom mask layer must be passed to the custom_objects argument.
#   warnings.warn('Custom mask layers require a config and must override '
# 2023-03-23 23:37:24.536487: W tensorflow/python/util/util.cc:368] Sets are not currently considered sequences, but this may change in the future, so consider avoiding using them.
# INFO:tensorflow:Assets written to: /home/andreaspr/plankton_classification/models/mobilenet/wandb/run-20230323_233131-ux8odzm8/files/model-best/assets
# /usr/local/lib/python3.8/dist-packages/keras/utils/generic_utils.py:494: CustomMaskWarning: Custom mask layers require a config and must override get_config. When loading, the custom mask layer must be passed to the custom_objects argument.
#   warnings.warn('Custom mask layers require a config and must override '
# wandb: Adding directory to artifact (/home/andreaspr/plankton_classification/models/mobilenet/wandb/run-20230323_233131-ux8odzm8/files/model-best)... Done. 0.1s
# Epoch 2/30
# 9306/9306 [==============================] - 322s 35ms/step - loss: 0.2095 - accuracy: 0.9377 - val_loss: 0.1578 - val_accuracy: 0.9531
# INFO:tensorflow:Assets written to: /home/andreaspr/plankton_classification/models/mobilenet/wandb/run-20230323_233131-ux8odzm8/files/model-best/assets
# /usr/local/lib/python3.8/dist-packages/keras/utils/generic_utils.py:494: CustomMaskWarning: Custom mask layers require a config and must override get_config. When loading, the custom mask layer must be passed to the custom_objects argument.
#   warnings.warn('Custom mask layers require a config and must override '
# wandb: Adding directory to artifact (/home/andreaspr/plankton_classification/models/mobilenet/wandb/run-20230323_233131-ux8odzm8/files/model-best)... Done. 0.1s
# Epoch 3/30
# 9306/9306 [==============================] - 316s 34ms/step - loss: 0.1988 - accuracy: 0.9414 - val_loss: 0.1606 - val_accuracy: 0.9536
# Epoch 4/30
# 9306/9306 [==============================] - 310s 33ms/step - loss: 0.1914 - accuracy: 0.9436 - val_loss: 0.1611 - val_accuracy: 0.9535
# Epoch 5/30
# 9306/9306 [==============================] - 307s 33ms/step - loss: 0.1867 - accuracy: 0.9455 - val_loss: 0.1567 - val_accuracy: 0.9557
# INFO:tensorflow:Assets written to: /home/andreaspr/plankton_classification/models/mobilenet/wandb/run-20230323_233131-ux8odzm8/files/model-best/assets
# /usr/local/lib/python3.8/dist-packages/keras/utils/generic_utils.py:494: CustomMaskWarning: Custom mask layers require a config and must override get_config. When loading, the custom mask layer must be passed to the custom_objects argument.
#   warnings.warn('Custom mask layers require a config and must override '
# wandb: Adding directory to artifact (/home/andreaspr/plankton_classification/models/mobilenet/wandb/run-20230323_233131-ux8odzm8/files/model-best)... Done. 0.1s
# Epoch 6/30
# 9306/9306 [==============================] - 314s 34ms/step - loss: 0.1834 - accuracy: 0.9468 - val_loss: 0.1638 - val_accuracy: 0.9547
# Epoch 7/30
# 9306/9306 [==============================] - 313s 34ms/step - loss: 0.1793 - accuracy: 0.9478 - val_loss: 0.1598 - val_accuracy: 0.9555
# Epoch 8/30
# 9306/9306 [==============================] - 311s 33ms/step - loss: 0.1773 - accuracy: 0.9492 - val_loss: 0.1686 - val_accuracy: 0.9563
# Epoch 9/30
# 9306/9306 [==============================] - 313s 34ms/step - loss: 0.1426 - accuracy: 0.9573 - val_loss: 0.1511 - val_accuracy: 0.9613
# INFO:tensorflow:Assets written to: /home/andreaspr/plankton_classification/models/mobilenet/wandb/run-20230323_233131-ux8odzm8/files/model-best/assets
# /usr/local/lib/python3.8/dist-packages/keras/utils/generic_utils.py:494: CustomMaskWarning: Custom mask layers require a config and must override get_config. When loading, the custom mask layer must be passed to the custom_objects argument.
#   warnings.warn('Custom mask layers require a config and must override '
# wandb: Adding directory to artifact (/home/andreaspr/plankton_classification/models/mobilenet/wandb/run-20230323_233131-ux8odzm8/files/model-best)... Done. 0.1s
# Epoch 10/30
# 9306/9306 [==============================] - 311s 33ms/step - loss: 0.1307 - accuracy: 0.9607 - val_loss: 0.1516 - val_accuracy: 0.9616
# Epoch 11/30
# 9306/9306 [==============================] - 311s 33ms/step - loss: 0.1263 - accuracy: 0.9621 - val_loss: 0.1511 - val_accuracy: 0.9617
# INFO:tensorflow:Assets written to: /home/andreaspr/plankton_classification/models/mobilenet/wandb/run-20230323_233131-ux8odzm8/files/model-best/assets
# /usr/local/lib/python3.8/dist-packages/keras/utils/generic_utils.py:494: CustomMaskWarning: Custom mask layers require a config and must override get_config. When loading, the custom mask layer must be passed to the custom_objects argument.
#   warnings.warn('Custom mask layers require a config and must override '
# wandb: Adding directory to artifact (/home/andreaspr/plankton_classification/models/mobilenet/wandb/run-20230323_233131-ux8odzm8/files/model-best)... Done. 0.1s
# Epoch 12/30
# 9306/9306 [==============================] - 313s 34ms/step - loss: 0.1233 - accuracy: 0.9626 - val_loss: 0.1516 - val_accuracy: 0.9618
# Epoch 13/30
# 9306/9306 [==============================] - 314s 34ms/step - loss: 0.1180 - accuracy: 0.9636 - val_loss: 0.1512 - val_accuracy: 0.9619
# Epoch 14/30
# 9306/9306 [==============================] - 313s 34ms/step - loss: 0.1173 - accuracy: 0.9640 - val_loss: 0.1507 - val_accuracy: 0.9620
# INFO:tensorflow:Assets written to: /home/andreaspr/plankton_classification/models/mobilenet/wandb/run-20230323_233131-ux8odzm8/files/model-best/assets
# /usr/local/lib/python3.8/dist-packages/keras/utils/generic_utils.py:494: CustomMaskWarning: Custom mask layers require a config and must override get_config. When loading, the custom mask layer must be passed to the custom_objects argument.
#   warnings.warn('Custom mask layers require a config and must override '
# wandb: Adding directory to artifact (/home/andreaspr/plankton_classification/models/mobilenet/wandb/run-20230323_233131-ux8odzm8/files/model-best)... Done. 0.1s
# Epoch 15/30
# 9306/9306 [==============================] - 307s 33ms/step - loss: 0.1169 - accuracy: 0.9640 - val_loss: 0.1506 - val_accuracy: 0.9624
# INFO:tensorflow:Assets written to: /home/andreaspr/plankton_classification/models/mobilenet/wandb/run-20230323_233131-ux8odzm8/files/model-best/assets
# /usr/local/lib/python3.8/dist-packages/keras/utils/generic_utils.py:494: CustomMaskWarning: Custom mask layers require a config and must override get_config. When loading, the custom mask layer must be passed to the custom_objects argument.
#   warnings.warn('Custom mask layers require a config and must override '
# wandb: Adding directory to artifact (/home/andreaspr/plankton_classification/models/mobilenet/wandb/run-20230323_233131-ux8odzm8/files/model-best)... Done. 0.1s
# Epoch 16/30
# 9306/9306 [==============================] - 314s 34ms/step - loss: 0.1163 - accuracy: 0.9641 - val_loss: 0.1506 - val_accuracy: 0.9621
# INFO:tensorflow:Assets written to: /home/andreaspr/plankton_classification/models/mobilenet/wandb/run-20230323_233131-ux8odzm8/files/model-best/assets
# /usr/local/lib/python3.8/dist-packages/keras/utils/generic_utils.py:494: CustomMaskWarning: Custom mask layers require a config and must override get_config. When loading, the custom mask layer must be passed to the custom_objects argument.
#   warnings.warn('Custom mask layers require a config and must override '
# wandb: Adding directory to artifact (/home/andreaspr/plankton_classification/models/mobilenet/wandb/run-20230323_233131-ux8odzm8/files/model-best)... Done. 0.1s
# Epoch 17/30
# 9306/9306 [==============================] - 308s 33ms/step - loss: 0.1160 - accuracy: 0.9644 - val_loss: 0.1508 - val_accuracy: 0.9621
# Epoch 18/30
# 9306/9306 [==============================] - 309s 33ms/step - loss: 0.1158 - accuracy: 0.9647 - val_loss: 0.1506 - val_accuracy: 0.9623
# Epoch 19/30
# 9306/9306 [==============================] - 309s 33ms/step - loss: 0.1146 - accuracy: 0.9647 - val_loss: 0.1508 - val_accuracy: 0.9622
# Epoch 20/30
# 9306/9306 [==============================] - 311s 33ms/step - loss: 0.1159 - accuracy: 0.9642 - val_loss: 0.1507 - val_accuracy: 0.9622
# Epoch 21/30
# 9306/9306 [==============================] - 308s 33ms/step - loss: 0.1145 - accuracy: 0.9645 - val_loss: 0.1508 - val_accuracy: 0.9622

# %%
wandb.finish()
# Out:
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>accuracy</td><td>▁▃▄▄▅▅▅▅▇▇███████████</td></tr><tr><td>epoch</td><td>▁▁▂▂▂▃▃▃▄▄▅▅▅▆▆▆▇▇▇██</td></tr><tr><td>loss</td><td>█▆▅▅▅▅▄▄▂▂▂▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>val_accuracy</td><td>▁▄▄▄▅▄▅▅▇████████████</td></tr><tr><td>val_loss</td><td>█▄▄▅▃▆▄▇▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>accuracy</td><td>0.96448</td></tr><tr><td>best_epoch</td><td>15</td></tr><tr><td>best_val_loss</td><td>0.15058</td></tr><tr><td>epoch</td><td>20</td></tr><tr><td>loss</td><td>0.11451</td></tr><tr><td>val_accuracy</td><td>0.9622</td></tr><tr><td>val_loss</td><td>0.15082</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">silver-hill-1</strong> at: <a href='https://wandb.ai/nubs/MobileNet/runs/ux8odzm8' target="_blank">https://wandb.ai/nubs/MobileNet/runs/ux8odzm8</a><br/>Synced 5 W&B file(s), 1 media file(s), 32 artifact file(s) and 1 other file(s)
# Find logs at: <code>./wandb/run-20230323_233131-ux8odzm8/logs</code>

# %%
# initialize wandb
wandb.init(project="MobileNet", config={"learning_rate": 0.001, "epochs": 30, "verbose": 1,"name": "MobileNetV3Small", "architecture": "MobileNetV3Small"})

# configs
cfg = wandb.config

# create the model
model = create_mobilenetv3_small_model(len(train_ds.class_names))
# Out:
# Tracking run with wandb version 0.14.0
# Run data is saved locally in <code>/home/andreaspr/plankton_classification/models/mobilenet/wandb/run-20230324_034324-yn6lu0z6</code>
# Syncing run <strong><a href='https://wandb.ai/nubs/MobileNet/runs/yn6lu0z6' target="_blank">ethereal-smoke-5</a></strong> to <a href='https://wandb.ai/nubs/MobileNet' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>
#  View project at <a href='https://wandb.ai/nubs/MobileNet' target="_blank">https://wandb.ai/nubs/MobileNet</a>
#  View run at <a href='https://wandb.ai/nubs/MobileNet/runs/yn6lu0z6' target="_blank">https://wandb.ai/nubs/MobileNet/runs/yn6lu0z6</a>

# %%
model.fit(train_ds, epochs=cfg.epochs, batch_size=32, verbose=cfg.verbose, validation_data=val_ds, callbacks=callbacks) # train the model
# Out:
# Epoch 1/30
# 9306/9306 [==============================] - 290s 31ms/step - loss: 0.2427 - accuracy: 0.9249 - val_loss: 0.1717 - val_accuracy: 0.9477
# /usr/local/lib/python3.8/dist-packages/keras/utils/generic_utils.py:494: CustomMaskWarning: Custom mask layers require a config and must override get_config. When loading, the custom mask layer must be passed to the custom_objects argument.
#   warnings.warn('Custom mask layers require a config and must override '
# INFO:tensorflow:Assets written to: /home/andreaspr/plankton_classification/models/mobilenet/wandb/run-20230324_034324-yn6lu0z6/files/model-best/assets
# /usr/local/lib/python3.8/dist-packages/keras/utils/generic_utils.py:494: CustomMaskWarning: Custom mask layers require a config and must override get_config. When loading, the custom mask layer must be passed to the custom_objects argument.
#   warnings.warn('Custom mask layers require a config and must override '
# wandb: Adding directory to artifact (/home/andreaspr/plankton_classification/models/mobilenet/wandb/run-20230324_034324-yn6lu0z6/files/model-best)... Done. 0.1s
# Epoch 2/30
# 9306/9306 [==============================] - 289s 31ms/step - loss: 0.2041 - accuracy: 0.9385 - val_loss: 0.1654 - val_accuracy: 0.9515
# INFO:tensorflow:Assets written to: /home/andreaspr/plankton_classification/models/mobilenet/wandb/run-20230324_034324-yn6lu0z6/files/model-best/assets
# /usr/local/lib/python3.8/dist-packages/keras/utils/generic_utils.py:494: CustomMaskWarning: Custom mask layers require a config and must override get_config. When loading, the custom mask layer must be passed to the custom_objects argument.
#   warnings.warn('Custom mask layers require a config and must override '
# wandb: Adding directory to artifact (/home/andreaspr/plankton_classification/models/mobilenet/wandb/run-20230324_034324-yn6lu0z6/files/model-best)... Done. 0.1s
# Epoch 3/30
# 9306/9306 [==============================] - 286s 31ms/step - loss: 0.1938 - accuracy: 0.9424 - val_loss: 0.1597 - val_accuracy: 0.9538
# INFO:tensorflow:Assets written to: /home/andreaspr/plankton_classification/models/mobilenet/wandb/run-20230324_034324-yn6lu0z6/files/model-best/assets
# /usr/local/lib/python3.8/dist-packages/keras/utils/generic_utils.py:494: CustomMaskWarning: Custom mask layers require a config and must override get_config. When loading, the custom mask layer must be passed to the custom_objects argument.
#   warnings.warn('Custom mask layers require a config and must override '
# wandb: Adding directory to artifact (/home/andreaspr/plankton_classification/models/mobilenet/wandb/run-20230324_034324-yn6lu0z6/files/model-best)... Done. 0.1s
# Epoch 4/30
# 9306/9306 [==============================] - 287s 31ms/step - loss: 0.1869 - accuracy: 0.9451 - val_loss: 0.1565 - val_accuracy: 0.9546
# INFO:tensorflow:Assets written to: /home/andreaspr/plankton_classification/models/mobilenet/wandb/run-20230324_034324-yn6lu0z6/files/model-best/assets
# /usr/local/lib/python3.8/dist-packages/keras/utils/generic_utils.py:494: CustomMaskWarning: Custom mask layers require a config and must override get_config. When loading, the custom mask layer must be passed to the custom_objects argument.
#   warnings.warn('Custom mask layers require a config and must override '
# wandb: Adding directory to artifact (/home/andreaspr/plankton_classification/models/mobilenet/wandb/run-20230324_034324-yn6lu0z6/files/model-best)... Done. 0.1s
# Epoch 5/30
# 9306/9306 [==============================] - 284s 31ms/step - loss: 0.1823 - accuracy: 0.9464 - val_loss: 0.1647 - val_accuracy: 0.9555
# Epoch 6/30
# 9306/9306 [==============================] - 284s 30ms/step - loss: 0.1777 - accuracy: 0.9481 - val_loss: 0.1588 - val_accuracy: 0.9560
# Epoch 7/30
# 9306/9306 [==============================] - 286s 31ms/step - loss: 0.1739 - accuracy: 0.9494 - val_loss: 0.1622 - val_accuracy: 0.9567
# Epoch 8/30
# 9306/9306 [==============================] - 262s 28ms/step - loss: 0.1406 - accuracy: 0.9582 - val_loss: 0.1467 - val_accuracy: 0.9603
# INFO:tensorflow:Assets written to: /home/andreaspr/plankton_classification/models/mobilenet/wandb/run-20230324_034324-yn6lu0z6/files/model-best/assets
# /usr/local/lib/python3.8/dist-packages/keras/utils/generic_utils.py:494: CustomMaskWarning: Custom mask layers require a config and must override get_config. When loading, the custom mask layer must be passed to the custom_objects argument.
#   warnings.warn('Custom mask layers require a config and must override '
# wandb: Adding directory to artifact (/home/andreaspr/plankton_classification/models/mobilenet/wandb/run-20230324_034324-yn6lu0z6/files/model-best)... Done. 0.1s
# Epoch 9/30
# 9306/9306 [==============================] - 264s 28ms/step - loss: 0.1304 - accuracy: 0.9611 - val_loss: 0.1460 - val_accuracy: 0.9611
# INFO:tensorflow:Assets written to: /home/andreaspr/plankton_classification/models/mobilenet/wandb/run-20230324_034324-yn6lu0z6/files/model-best/assets
# /usr/local/lib/python3.8/dist-packages/keras/utils/generic_utils.py:494: CustomMaskWarning: Custom mask layers require a config and must override get_config. When loading, the custom mask layer must be passed to the custom_objects argument.
#   warnings.warn('Custom mask layers require a config and must override '
# wandb: Adding directory to artifact (/home/andreaspr/plankton_classification/models/mobilenet/wandb/run-20230324_034324-yn6lu0z6/files/model-best)... Done. 0.1s
# Epoch 10/30
# 9306/9306 [==============================] - 265s 28ms/step - loss: 0.1259 - accuracy: 0.9620 - val_loss: 0.1479 - val_accuracy: 0.9611
# Epoch 11/30
# 9306/9306 [==============================] - 255s 27ms/step - loss: 0.1224 - accuracy: 0.9631 - val_loss: 0.1479 - val_accuracy: 0.9615
# Epoch 12/30
# 9306/9306 [==============================] - 260s 28ms/step - loss: 0.1192 - accuracy: 0.9639 - val_loss: 0.1483 - val_accuracy: 0.9611
# Epoch 13/30
# 9306/9306 [==============================] - 253s 27ms/step - loss: 0.1149 - accuracy: 0.9650 - val_loss: 0.1469 - val_accuracy: 0.9614
# Epoch 14/30
# 9306/9306 [==============================] - 256s 27ms/step - loss: 0.1136 - accuracy: 0.9652 - val_loss: 0.1466 - val_accuracy: 0.9617
# Epoch 15/30
# 9306/9306 [==============================] - 255s 27ms/step - loss: 0.1134 - accuracy: 0.9653 - val_loss: 0.1467 - val_accuracy: 0.9617
# Epoch 16/30
# 9306/9306 [==============================] - 255s 27ms/step - loss: 0.1135 - accuracy: 0.9652 - val_loss: 0.1465 - val_accuracy: 0.9618
# Epoch 17/30
# 9306/9306 [==============================] - 255s 27ms/step - loss: 0.1126 - accuracy: 0.9653 - val_loss: 0.1465 - val_accuracy: 0.9618
# Epoch 18/30
# 9306/9306 [==============================] - 256s 28ms/step - loss: 0.1114 - accuracy: 0.9658 - val_loss: 0.1465 - val_accuracy: 0.9617
# Epoch 19/30
# 9306/9306 [==============================] - 254s 27ms/step - loss: 0.1118 - accuracy: 0.9659 - val_loss: 0.1466 - val_accuracy: 0.9618

# %%
wandb.finish()
# Out:
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>accuracy</td><td>▁▃▄▄▅▅▅▇▇▇█████████</td></tr><tr><td>epoch</td><td>▁▁▂▂▃▃▃▄▄▅▅▅▆▆▆▇▇██</td></tr><tr><td>loss</td><td>█▆▅▅▅▅▄▃▂▂▂▁▁▁▁▁▁▁▁</td></tr><tr><td>val_accuracy</td><td>▁▃▄▄▅▅▅▇███████████</td></tr><tr><td>val_loss</td><td>█▆▅▄▆▅▅▁▁▂▂▂▁▁▁▁▁▁▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>accuracy</td><td>0.96589</td></tr><tr><td>best_epoch</td><td>8</td></tr><tr><td>best_val_loss</td><td>0.14602</td></tr><tr><td>epoch</td><td>18</td></tr><tr><td>loss</td><td>0.11177</td></tr><tr><td>val_accuracy</td><td>0.96182</td></tr><tr><td>val_loss</td><td>0.14662</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">ethereal-smoke-5</strong> at: <a href='https://wandb.ai/nubs/MobileNet/runs/yn6lu0z6' target="_blank">https://wandb.ai/nubs/MobileNet/runs/yn6lu0z6</a><br/>Synced 5 W&B file(s), 1 media file(s), 24 artifact file(s) and 1 other file(s)
# Find logs at: <code>./wandb/run-20230324_034324-yn6lu0z6/logs</code>
